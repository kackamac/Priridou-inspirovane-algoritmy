# %% [markdown]
# # Neuronové sítě
#
# Dnes se podíváme na další přírodou inspirované techniky strojového učení -- neuronové sítě. Neuronová síť je výpočetní model určený pro zpracování dat inspirovaný nervovou soustavou. Skládá se z jednotlivých neuronů, které vypadají a fungují na podobné bázi jako neurony v mozku a které jsou navzájem propojené a transformují a dále si předávají signál, který jimi prochází.
#
# Mezi nejjednodušší modely patří perceptron a vícevrstevný perceptron. Na cvičení si je zkusíme sami naiplementovat.
#
# ## Perceptron
#
# Perceptron je vlastně jeden neuron. Každý neuron má libovolný počet vstupů, ale pouze jeden výstup. Každý vstup má navíc váhu, která určuje, jak moc je důležitý a jak moc ovlivňuje výslednou hodnotu. Neuron v sobě také obsahuje aktivační funkci, pomocí které vstupní signál transformuje do určitého intervalu a práh, podle kterého se rozhoduje, jestli bude nauron aktivní nebo ne. Užití perceptronu je velmi omezené, protože ho lze použít pouze na množiny, které jsou lineárně separovatelné.

# %%
import numpy as np
from sklearn import datasets
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import collections

# %% [markdown]
# Zkusíme si tedy naimplementovat jednoduchý perceptronový algoritmus učení.  K tomu budeme potřebovat třídu ```Perceptron```, kde si definujeme, jak jednoduchý perceptron vypadá. Při inicializaci se nastaví maximální počet iterací a learning rate, který určuje rychlost učení algoritmu, a přípraví se prázdná matice vah rozšířená o jeden sloupeček samých 1, který bude simulovat přičtení prahu.
#
# Perceptron má na vstupu vektor příznaků a vrací jeden výstup jakožto hodnotu přenosové funkce pro daný vstup. Funkce ```predict``` nám tedy pro daný vstup bude predikovat jeho výstup tak, že se spočítá hodnota aktivační funkce ve vstupním bodě a pokud bude větší než 0, bude aktivace 1, jinak bude aktivace 0 (někdy se také může hodit vracet -1 namísto 0).
#
# Důležité je ještě správně nastavit váhy tak, aby nám neuron dával správné výstupy pro dané vstupy. K tomu budeme potřebovat váhy natrénovat podle vstupních dat a výstupních labelů. K tomu budeme potřebovat ještě funkci ```fit```, kde pro daný vstup spočteme jeho predikovaný výstup a pokud je špatný, tak upravíme váhy tak, aby příště predikoval výstup správně.

# %%
class Perceptron:
    def __init__(self, max_iterations, number_of_inputs, learning_rate=0.1):
        self.max_iterations = max_iterations
        self.learning_rate = learning_rate
        self.weights = np.random.normal(size=number_of_inputs+1)
        
    def predict(self, inputs):
        # spocitame vystup funkce pro dany vstup, vahy a prah
        activation = np.dot(inputs, self.weights[1:]) + self.weights[0]
        # spocitame aktivaci z funkce sgn do {-1,1} a to prevedeme na {0,1}
        return (np.sign(activation)+1)/2
    
    
    def fit(self, inputs, labels):
        for i in range(self.max_iterations):
            for x, y in zip(inputs, labels):
                prediction = self.predict(x)               
                # aktualizujem vahy a prahy
                self.weights[1:] += self.learning_rate * (y - prediction) * x
                self.weights[0] += self.learning_rate * (y - prediction)

# %% [markdown]
# Abychom náš perceptron otestovali, vygenerujem si náhodná data pomocí knihovny *scikit-learn*, která nám umí vrátit 2 lineárně separabilí třídy bodů.

# %%
inputs, labels = datasets.make_blobs(centers=2, n_samples=200)
perc = Perceptron(100,2)
perc.fit(inputs, labels)

# %% [markdown]
# Vytvořená data si zobrazíme a vidíme dvě krásně lineárně separovatelné množiny.

# %%
plt.figure(figsize=(12,8))
plt.scatter(inputs[:,0], inputs[:,1], c=labels)
plt.show()

# %% [markdown]
# Zkusíme si tedy pustit perceptronový algoritmus učení a natrénovat váhy tak, aby nám uměl rozdělit data na dvě disjunktní množiny.

# %%
perc = Perceptron(100,2)
perc.fit(inputs, labels)

# %% [markdown]
# Ještě by bylo dobré umět si vizualizovat i výsledky, a proto si napíšeme následující funkci, která bude umět vykreslit data i oddělující nadrovinu.

# %%
def draw_boundary(model, inputs, labels):
    
    x_min = inputs[:, 0].min() - 1
    x_max = inputs[:, 0].max() + 1
    y_min = inputs[:, 1].min() - 1 
    y_max = inputs[:, 1].max() + 1

    # vytvori obdelnikovou mrizku s vyse spocitanymi rozmery
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    
    # vykresleni rozhodovaci hranice -- kazdemu bodu se podle tho priradi barva
    predicted = model.predict(np.c_[xx.ravel(), yy.ravel()])
    predicted = predicted.reshape(xx.shape)
    
    plt.figure(figsize=(12,8))
    plt.scatter(inputs[:,0], inputs[:,1], c=labels)
    plt.contourf(xx, yy, predicted, alpha=0.4)
    plt.show()
    
draw_boundary(perc, inputs, labels)

# %% [markdown]
# ## Vícevrstvý perceptron

# %% [markdown]
# Jak už bylo zmíněno výše, tak perceptronový algoritmus se dá použít jen v případě lineárně separovatelných dat. Často ale máme lineárně neseparovatelná data, která bychom také chtěli umět rozdělit na podmožniny. K tomu nám ale postačí zkombinovat více jednoduchých neuronů dohromady. Tím nám vznikne neuronová síť neboli vícevrstevný perceptron, kde přidáváním perceptronů do více vrstev rozšiřujeme separabilní schopnosti celého modelu. První vrstva se nazývá vstupní a poslední vrstva výstupní. Mezi nimi se může nacházet libovolné množství skrytých vrstev.
#
# Neuronové sítě patří do skupiny učení s učitelem, tedy na vstupu vyžadují data ve tvaru vstupní vektor příznaků a odpovídající výstupní hodnota. Průchod sítí pak vypadá tak, že se pro každý vstup spočítá výstup. Pak se spočítá chyba jakožto druhá mocnina rozdílu predikovaného výstupu a skutečného výstupu. Ta se potom zpětně propaguje až k vstupní vrstvě a updatují se váhy tak, aby se v příštím průchodu pro dané vstupy predikovaly správné výstupy. Tomuto zpětnému průchodu se říká backpropagace a slouží právě k natrénování vah neuronové sítě, které se začátku nastaví náhodně a pak se upravují, aby síť predikovala data správně.
#
# Nyní už pojďme na samotnou implementaci. Jednoduchý perceptron už umíme, tak si nyní s jeho pomocí zkusíme napsat vícevrstevný perceptron, neboli celou neuronovou síť. V inicializační části nastavíme velikosti vrstev a poté matice vah mezi jednotlivými vrstvami jakožto náhodné hodnoty. Dále bude potřeba funkce predikce, která pro daný vstup spočítá výstup sítě a následně updatuje váhy pomocí backpropagace. Nakonec bude třeba už jen umět predikovat výstupní hodnotu sítě pro daný vstup.

# %%
class MultiLayerPerceptron:
    def __init__(self, layer_sizes,alpha=0.1):
        self.layer_sizes = layer_sizes
        self.layers = []
        self.alpha = alpha
        
        #for (p, n) in zip(self.layer_sizes, self.layer_sizes[1:]):
        #    self.layers.append(np.random.normal(size=(p+1, n)))
            
        for i in range(0,len(self.layer_sizes)-1):
            self.layers.append(np.random.normal(size=(self.layer_sizes[i]+1,self.layer_sizes[i+1])))
            
    def predict(self, X):
        activations = np.array(X)
        try:
            for layer in self.layers:
                activations = 1/(1+np.exp(np.dot(activations, layer[1:])+layer[0]))
                #activations_1 = self._add_ones(activations) # pridame 1 misto prahu
                #activations = 1/(1+np.exp(np.dot(activations_1, layer)))
        except Exception as e:
            print("Activations:", activations)
            raise e

        return activations
    
    def fit(self, inputs, outputs):
        pass
        # je potreba spocitat vystup site
        # pak je potreba update vah pomoci backpropagace
        # zkuste si dopsat sami :P
        
    # pridame sloupecek jednicek k neuronum misto prahu     
    def _add_ones(self, x):
        ones = np.ones(shape=(x.shape[0],1))
        x = np.append(ones,x, axis=1)        
        return x

# %% [markdown]
# Nyní si náhodně vygenerujeme data a ověříme, že náš vícevrstevný perceptron opravdu něco dělá.

# %%
mlp = MultiLayerPerceptron([3,5,2])
mlp.predict(np.array([[1,2,3], [1,2,7]]))
# Out:
# array([[0.06574172, 0.29327807],
#        [0.08023216, 0.27384667]])

# %% [markdown]
# ## Wine-quality dataset
#
# Zkusíme si neuronovou síť pustit na něčem zajímavějším než na náhodných datech. Podíváme se na *winequality-white.csv* dataset, který pochází z UCI machine learning repository. Cílem u tohoto datasetu je predikovat kvalitu vína na základě 12 změřených fyzikálních a chemických vlastností. Kvalita se hodnotí na stupnici 0-10. Schválně si dataset načtěme a podívejme se, jak vypadá.

# %%
data = pd.read_csv('winequality-white.csv', delimiter=';')
print(data.head(5))
data.describe()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %% [markdown]
# Spočítejme si pro zajímavost rozložení výsledných hodnot kvality vín v datasetu.

# %%
counter=collections.Counter(data['quality'])
print(counter)
# Out:
# Counter({6: 2198, 5: 1457, 7: 880, 8: 175, 4: 163, 3: 20, 9: 5})

# %% [markdown]
# Z výsledků vidíme, že stupnice kvality je sice na škále 0-10, ale většina výstupů je mezi 5-7 a některé se nám tu ani nevyskytují. Proto si zjednoduššíme práci a dataset si upravíme tak, aby predikoval jen 3 výstupní kategorie s hodnotami 5, 6, 7 tak, že 3 a 4 sloučíme se 5 a zároveň 9 a 8 sloučíme se 7.

# %%
data['quality'].replace({3: 5, 4: 5, 8: 7, 9: 7}, inplace=True)
counter=collections.Counter(data['quality'])
print(counter)
# Out:
# Counter({6: 2198, 5: 1640, 7: 1060})

# %% [markdown]
#  Na tomto upraveném datasetu si nyní zkusíme pustit vícevrstevný perceptron.

# %%
k = 10 
mlp = MultiLayerPerceptron([len(data.columns),k,data.quality.nunique()])
mlp.predict(data)
# Out:
# C:\Users\katie\AppData\Local\Temp\ipykernel_14492\923626329.py:17: RuntimeWarning: overflow encountered in exp
#   activations = 1/(1+np.exp(np.dot(activations, layer[1:])+layer[0]))
# array([[0.4517709 , 0.97866328, 0.01044542],
#        [0.45177088, 0.97866328, 0.01044542],
#        [0.317984  , 0.9008472 , 0.02138527],
#        ...,
#        [0.43212554, 0.97357249, 0.01157279],
#        [0.29573906, 0.86646198, 0.02411755],
#        [0.27118459, 0.82207552, 0.02806325]])

# %% [markdown]
# ## Úkol na cvičení
#
# Vidíme, že výsledky jsou nám k ničemu, protože jednotlivé neurony predikují náhodné hodnoty. Matice vah se totiž nastavuje v initu náhodně a už neprobíhá žádné updatování vah tak, aby síť predkovala něco smyslupnějšího. Proto teď s velkou slávou přichází úkol na cvíčení. Zkuste si doprogramovat funkci ```fit``` a natrénovat váhy pomocí algoritmu backpropagace, aby síť predikovala pro náš vínový dataset nějaké smysluplnější hodnoty.

# %% [markdown]
# ## Knihovny tensorflow, keras, scikit-learn
#
# Nejprve se seznámíme s pár základními knihovnami, které budeme používat pro snažší vytváření neuronových sítí a práci s nimi. Knihovna *tensorflow* je symbolická matematická knihovna, která slouží pro dataflow, tedy obsahuje grafové moduly a operace, nad kterými se následně dají implementovat různé algoritmy strojového učení. Nad ní běží knihovna *keras*, která je navržena pro snadné experimentování s hlubokýcmi neuronovými sítěmi. Knihovna *scikit-learn* zase obsahuje všechny možné běžné algoritmy strojového učení.
#
# Všechny tyto knihovny byly navrženy, aby uživateli zjednodušily práci se zpracováním dat a následné vytváření predikčních a jiných modelů, ať už pomocí neurovnových sítí nebo jiných algoritmů strojového učení.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import metrics
import pylab as pl
from sklearn import preprocessing
from sklearn.utils import shuffle

# %% [markdown]
# Zkusíme si tedy s pomocí těchto knihoven naimplementovat tu samou jednoduchou neuronovou sít, jako jsme si ručně psali výše. Budeme potřebovat si vyrobit data, potom definovat síť a nakonec ji natrénovat na trénovacích datech a nechat ji predikovat a změřit chybu na testovacích datech.
#
# Nejprve si vytvoříme náhodná dvojrozměrná data klasifikovatelná do $n$ tříd, abychom si je mohli i hezky vizualizovat v grafu. K tomu bude potřeba si upravit funkci pro vizualizaci, protože vícetřídová klasifikace nám vrací výstup jakožte pole, kde pro tu jednu vybranou třídu (ideálně) bude na jejím indexu 1 a všude jinde budou 0. Tomuto výstupu se tak říká one-hot-encoding.

# %%
def draw_boundary(model, inputs, labels):
    x_min = inputs[:, 0].min() - 1
    x_max = inputs[:, 0].max() + 1
    y_min = inputs[:, 1].min() - 1 
    y_max = inputs[:, 1].max() + 1

    # vytvori obdelnikovou mrizku s vyse spocitanymi rozmery
    xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1), np.arange(y_min, y_max, 0.1))
    
    # vykresleni rozhodovaci hranice -- kazdemu bodu se podle tho priradi barva
    predicted = model.predict(np.c_[xx.ravel(), yy.ravel()])
    
    # pridana radka pro vyber klasifikovane tridy
    predicted = np.argmax(predicted, axis=1)
    
    predicted = predicted.reshape(xx.shape)
    
    plt.figure(figsize=(12,8))
    plt.scatter(inputs[:,0], inputs[:,1], c=labels)
    plt.contourf(xx, yy, predicted, alpha=0.4)
    plt.show()
    model.predict(x_test[:10])

# %% [markdown]
# Když mám upravenou funkci pro vizualizaci, tak si vygeneruji náhodná data a podívám se, jak byl model úspěšný. Tedy si rozdělím data na trénovací a testovací a podívám se, jak dobře se model natrénoval na trénovacích datech a jak dobře umí predikovat testovací data.

# %%
# priprava dat a rozdeleni na trenovaci a testovaci mnoziny
n = 3
x, y = datasets.make_blobs(n_samples=300, centers=n)

x_train, x_test = x[:250], x[250:]
y_train, y_test = y[:250], y[250:]

# definujeme architekturu site
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, activation=tf.nn.sigmoid))
model.add(tf.keras.layers.Dense(n, activation=tf.nn.softmax))

# nastavime optimalizaci
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# trenovani site na trenovacich datech
model.fit(x_train, y_train, epochs=200, verbose=1)

# predpovedi na trenovacich datech
draw_boundary(model, x_test, y_test)
# Out:
# Epoch 1/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.6017 - accuracy: 0.0080
# Epoch 2/200
# 8/8 [==============================] - 0s 355us/step - loss: 1.5207 - accuracy: 0.0080
# Epoch 3/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.4509 - accuracy: 0.0080
# Epoch 4/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3915 - accuracy: 0.0080
# Epoch 5/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.3401 - accuracy: 0.0040
# Epoch 6/200
# 8/8 [==============================] - 0s 3ms/step - loss: 1.2962 - accuracy: 0.0040
# Epoch 7/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.2577 - accuracy: 0.0040
# Epoch 8/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.2239 - accuracy: 0.0040
# Epoch 9/200
# 8/8 [==============================] - 0s 949us/step - loss: 1.1938 - accuracy: 0.0040
# Epoch 10/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1672 - accuracy: 0.0040
# Epoch 11/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1429 - accuracy: 0.0040
# Epoch 12/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1204 - accuracy: 0.1280
# Epoch 13/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1000 - accuracy: 0.3760
# Epoch 14/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.0810 - accuracy: 0.3880
# Epoch 15/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.0626 - accuracy: 0.4120
# Epoch 16/200
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0457 - accuracy: 0.4440
# Epoch 17/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.0297 - accuracy: 0.4800
# Epoch 18/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.0144 - accuracy: 0.5560
# Epoch 19/200
# 8/8 [==============================] - 0s 1ms/step - loss: 1.0000 - accuracy: 0.5680
# Epoch 20/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9862 - accuracy: 0.5880
# Epoch 21/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9732 - accuracy: 0.6040
# Epoch 22/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9607 - accuracy: 0.6320
# Epoch 23/200
# 8/8 [==============================] - 0s 864us/step - loss: 0.9489 - accuracy: 0.6400
# Epoch 24/200
# 8/8 [==============================] - 0s 704us/step - loss: 0.9379 - accuracy: 0.6520
# Epoch 25/200
# 8/8 [==============================] - 0s 698us/step - loss: 0.9275 - accuracy: 0.6560
# Epoch 26/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9175 - accuracy: 0.6600
# Epoch 27/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.9084 - accuracy: 0.6600
# Epoch 28/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8996 - accuracy: 0.6600
# Epoch 29/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8912 - accuracy: 0.6640
# Epoch 30/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8833 - accuracy: 0.6720
# Epoch 31/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8759 - accuracy: 0.6720
# Epoch 32/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8686 - accuracy: 0.6720
# Epoch 33/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8620 - accuracy: 0.6720
# Epoch 34/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8553 - accuracy: 0.6720
# Epoch 35/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8491 - accuracy: 0.6720
# Epoch 36/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8431 - accuracy: 0.6720
# Epoch 37/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8373 - accuracy: 0.6720
# Epoch 38/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8318 - accuracy: 0.6720
# Epoch 39/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8265 - accuracy: 0.6720
# Epoch 40/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8211 - accuracy: 0.6760
# Epoch 41/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8161 - accuracy: 0.6760
# Epoch 42/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8115 - accuracy: 0.6760
# Epoch 43/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.8066 - accuracy: 0.6760
# Epoch 44/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.8022 - accuracy: 0.6760
# Epoch 45/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7976 - accuracy: 0.6760
# Epoch 46/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7931 - accuracy: 0.6760
# Epoch 47/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7889 - accuracy: 0.6760
# Epoch 48/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7847 - accuracy: 0.6760
# Epoch 49/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7809 - accuracy: 0.6760
# Epoch 50/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7767 - accuracy: 0.6760
# Epoch 51/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7729 - accuracy: 0.6760
# Epoch 52/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7694 - accuracy: 0.6760
# Epoch 53/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7655 - accuracy: 0.6760
# Epoch 54/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7620 - accuracy: 0.6760
# Epoch 55/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7586 - accuracy: 0.6760
# Epoch 56/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7546 - accuracy: 0.6760
# Epoch 57/200
# 8/8 [==============================] - 0s 585us/step - loss: 0.7511 - accuracy: 0.6760
# Epoch 58/200
# 8/8 [==============================] - 0s 838us/step - loss: 0.7478 - accuracy: 0.6760
# Epoch 59/200
# 8/8 [==============================] - 0s 586us/step - loss: 0.7445 - accuracy: 0.6760
# Epoch 60/200
# 8/8 [==============================] - 0s 655us/step - loss: 0.7411 - accuracy: 0.6760
# Epoch 61/200
# 8/8 [==============================] - 0s 971us/step - loss: 0.7379 - accuracy: 0.6760
# Epoch 62/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7348 - accuracy: 0.6760
# Epoch 63/200
# 8/8 [==============================] - 0s 839us/step - loss: 0.7318 - accuracy: 0.6760
# Epoch 64/200
# 8/8 [==============================] - 0s 698us/step - loss: 0.7285 - accuracy: 0.6760
# Epoch 65/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7256 - accuracy: 0.6760
# Epoch 66/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7225 - accuracy: 0.6760
# Epoch 67/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7195 - accuracy: 0.6760
# Epoch 68/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7165 - accuracy: 0.6760
# Epoch 69/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7139 - accuracy: 0.7520
# Epoch 70/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7110 - accuracy: 0.6840
# Epoch 71/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7079 - accuracy: 0.6760
# Epoch 72/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7052 - accuracy: 0.7080
# Epoch 73/200
# 8/8 [==============================] - 0s 743us/step - loss: 0.7027 - accuracy: 0.7360
# Epoch 74/200
# 8/8 [==============================] - 0s 841us/step - loss: 0.6995 - accuracy: 0.6760
# Epoch 75/200
# 8/8 [==============================] - 0s 779us/step - loss: 0.6969 - accuracy: 0.6760
# Epoch 76/200
# 8/8 [==============================] - 0s 828us/step - loss: 0.6941 - accuracy: 0.7720
# Epoch 77/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6912 - accuracy: 0.6760
# Epoch 78/200
# 8/8 [==============================] - 0s 759us/step - loss: 0.6888 - accuracy: 0.8600
# Epoch 79/200
# 8/8 [==============================] - 0s 736us/step - loss: 0.6857 - accuracy: 0.7640
# Epoch 80/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6829 - accuracy: 0.8840
# Epoch 81/200
# 8/8 [==============================] - 0s 791us/step - loss: 0.6802 - accuracy: 0.6760
# Epoch 82/200
# 8/8 [==============================] - 0s 727us/step - loss: 0.6774 - accuracy: 0.8560
# Epoch 83/200
# 8/8 [==============================] - 0s 616us/step - loss: 0.6746 - accuracy: 0.7880
# Epoch 84/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6717 - accuracy: 0.8760
# Epoch 85/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6689 - accuracy: 0.6800
# Epoch 86/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6659 - accuracy: 0.7360
# Epoch 87/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6627 - accuracy: 0.8360
# Epoch 88/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6595 - accuracy: 0.8720
# Epoch 89/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6563 - accuracy: 0.9400
# Epoch 90/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6531 - accuracy: 0.9440
# Epoch 91/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6497 - accuracy: 0.8600
# Epoch 92/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6459 - accuracy: 0.9440
# Epoch 93/200
# 8/8 [==============================] - 0s 823us/step - loss: 0.6422 - accuracy: 0.9520
# Epoch 94/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6381 - accuracy: 0.9360
# Epoch 95/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6339 - accuracy: 0.9480
# Epoch 96/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6297 - accuracy: 0.9440
# Epoch 97/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6250 - accuracy: 0.9520
# Epoch 98/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6202 - accuracy: 0.9520
# Epoch 99/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6156 - accuracy: 0.9320
# Epoch 100/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6102 - accuracy: 0.9320
# Epoch 101/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6052 - accuracy: 0.9360
# Epoch 102/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6004 - accuracy: 0.9400
# Epoch 103/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5956 - accuracy: 0.9200
# Epoch 104/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5907 - accuracy: 0.9400
# Epoch 105/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5864 - accuracy: 0.9280
# Epoch 106/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5819 - accuracy: 0.9280
# Epoch 107/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5778 - accuracy: 0.9200
# Epoch 108/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5742 - accuracy: 0.9160
# Epoch 109/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5703 - accuracy: 0.9120
# Epoch 110/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5670 - accuracy: 0.9120
# Epoch 111/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5639 - accuracy: 0.9160
# Epoch 112/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5606 - accuracy: 0.9120
# Epoch 113/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5574 - accuracy: 0.9160
# Epoch 114/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5546 - accuracy: 0.9120
# Epoch 115/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5516 - accuracy: 0.9080
# Epoch 116/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5488 - accuracy: 0.9160
# Epoch 117/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5462 - accuracy: 0.9080
# Epoch 118/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5433 - accuracy: 0.9160
# Epoch 119/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5406 - accuracy: 0.9160
# Epoch 120/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5377 - accuracy: 0.9120
# Epoch 121/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5350 - accuracy: 0.9120
# Epoch 122/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5323 - accuracy: 0.9160
# Epoch 123/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5297 - accuracy: 0.9080
# Epoch 124/200
# 8/8 [==============================] - 0s 866us/step - loss: 0.5268 - accuracy: 0.9360
# Epoch 125/200
# 8/8 [==============================] - 0s 836us/step - loss: 0.5236 - accuracy: 0.9400
# Epoch 126/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5209 - accuracy: 0.9320
# Epoch 127/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5179 - accuracy: 0.9280
# Epoch 128/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5149 - accuracy: 0.9400
# Epoch 129/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5117 - accuracy: 0.9400
# Epoch 130/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5088 - accuracy: 0.9400
# Epoch 131/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5055 - accuracy: 0.9440
# Epoch 132/200
# 8/8 [==============================] - 0s 778us/step - loss: 0.5024 - accuracy: 0.9400
# Epoch 133/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4990 - accuracy: 0.9400
# Epoch 134/200
# 8/8 [==============================] - 0s 965us/step - loss: 0.4957 - accuracy: 0.9400
# Epoch 135/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4925 - accuracy: 0.9400
# Epoch 136/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4891 - accuracy: 0.9400
# Epoch 137/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4857 - accuracy: 0.9400
# Epoch 138/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4826 - accuracy: 0.9360
# Epoch 139/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4794 - accuracy: 0.9400
# Epoch 140/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4760 - accuracy: 0.9360
# Epoch 141/200
# 8/8 [==============================] - 0s 500us/step - loss: 0.4728 - accuracy: 0.9400
# Epoch 142/200
# 8/8 [==============================] - 0s 775us/step - loss: 0.4699 - accuracy: 0.9400
# Epoch 143/200
# 8/8 [==============================] - 0s 959us/step - loss: 0.4668 - accuracy: 0.9400
# Epoch 144/200
# 8/8 [==============================] - 0s 981us/step - loss: 0.4639 - accuracy: 0.9360
# Epoch 145/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4612 - accuracy: 0.9400
# Epoch 146/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4585 - accuracy: 0.9440
# Epoch 147/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4559 - accuracy: 0.9440
# Epoch 148/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4531 - accuracy: 0.9400
# Epoch 149/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4509 - accuracy: 0.9280
# Epoch 150/200
# 8/8 [==============================] - 0s 388us/step - loss: 0.4485 - accuracy: 0.9400
# Epoch 151/200
# 8/8 [==============================] - 0s 580us/step - loss: 0.4466 - accuracy: 0.9400
# Epoch 152/200
# 8/8 [==============================] - 0s 685us/step - loss: 0.4442 - accuracy: 0.9360
# Epoch 153/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4422 - accuracy: 0.9280
# Epoch 154/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4403 - accuracy: 0.9240
# Epoch 155/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4382 - accuracy: 0.9320
# Epoch 156/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4363 - accuracy: 0.9360
# Epoch 157/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4344 - accuracy: 0.9320
# Epoch 158/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4327 - accuracy: 0.9360
# Epoch 159/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4308 - accuracy: 0.9400
# Epoch 160/200
# 8/8 [==============================] - 0s 658us/step - loss: 0.4294 - accuracy: 0.9400
# Epoch 161/200
# 8/8 [==============================] - 0s 746us/step - loss: 0.4274 - accuracy: 0.9360
# Epoch 162/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4257 - accuracy: 0.9280
# Epoch 163/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4240 - accuracy: 0.9400
# Epoch 164/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4226 - accuracy: 0.9320
# Epoch 165/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4210 - accuracy: 0.9320
# Epoch 166/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4196 - accuracy: 0.9360
# Epoch 167/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4179 - accuracy: 0.9320
# Epoch 168/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4164 - accuracy: 0.9400
# Epoch 169/200
# 8/8 [==============================] - 0s 603us/step - loss: 0.4151 - accuracy: 0.9400
# Epoch 170/200
# 8/8 [==============================] - 0s 821us/step - loss: 0.4134 - accuracy: 0.9400
# Epoch 171/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4121 - accuracy: 0.9440
# Epoch 172/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4107 - accuracy: 0.9360
# Epoch 173/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4090 - accuracy: 0.9360
# Epoch 174/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4076 - accuracy: 0.9400
# Epoch 175/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4062 - accuracy: 0.9400
# Epoch 176/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4050 - accuracy: 0.9360
# Epoch 177/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4036 - accuracy: 0.9400
# Epoch 178/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4021 - accuracy: 0.9400
# Epoch 179/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4009 - accuracy: 0.9320
# Epoch 180/200
# 8/8 [==============================] - 0s 223us/step - loss: 0.3994 - accuracy: 0.9400
# Epoch 181/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3979 - accuracy: 0.9440
# Epoch 182/200
# 8/8 [==============================] - 0s 797us/step - loss: 0.3967 - accuracy: 0.9360
# Epoch 183/200
# 8/8 [==============================] - 0s 850us/step - loss: 0.3955 - accuracy: 0.9400
# Epoch 184/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.9400
# Epoch 185/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.9360
# Epoch 186/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3914 - accuracy: 0.9440
# Epoch 187/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3906 - accuracy: 0.9360
# Epoch 188/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3889 - accuracy: 0.9400
# Epoch 189/200
# 8/8 [==============================] - 0s 315us/step - loss: 0.3877 - accuracy: 0.9400
# Epoch 190/200
# 8/8 [==============================] - 0s 454us/step - loss: 0.3866 - accuracy: 0.9400
# Epoch 191/200
# 8/8 [==============================] - 0s 965us/step - loss: 0.3855 - accuracy: 0.9360
# Epoch 192/200
# 8/8 [==============================] - 0s 859us/step - loss: 0.3841 - accuracy: 0.9400
# Epoch 193/200
# 8/8 [==============================] - 0s 920us/step - loss: 0.3829 - accuracy: 0.9400
# Epoch 194/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3820 - accuracy: 0.9360
# Epoch 195/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3803 - accuracy: 0.9400
# Epoch 196/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3794 - accuracy: 0.9400
# Epoch 197/200
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3781 - accuracy: 0.9440
# Epoch 198/200
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3768 - accuracy: 0.9400
# Epoch 199/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3759 - accuracy: 0.9360
# Epoch 200/200
# 8/8 [==============================] - 0s 1ms/step - loss: 0.3745 - accuracy: 0.9440
# 711/711 [==============================] - 1s 1ms/step
# 1/1 [==============================] - 0s 22ms/step

# %% [markdown]
# Ještě si zkusíme pustit neuronovou síť z tensorflow na nějakém reálném datasetu. Nejjednodušší volbou je dataset o víně, který jsme si už popsali výše. Aby však síť mohla správně klasifikovat labely, je potřeba je posunout z množiny {5, 6, 7} do množiny {0, 1, 2}. Následně ještě provedeme normalizaci ostatních hodnot tak, že všechny budou sloupečky budou mít hodnoty v intervalu [0, 1]. Normalizace se dělá proto, aby se nestalo, že některý sloupeček s hodně vysokými hodnotami bude mít příliš velký vliv na výsledný label, a mohl by potom data zkreslovat.

# %%
# nahodne zamichani dat
data = shuffle(data)

# posun vystupnich labelu
data['quality'].replace({5: 0, 6: 1, 7: 2}, inplace=True)
labels = data['quality'].values

# normalizace dat
values = data[data.columns.difference(['quality'])].values
min_max_scaler = preprocessing.MinMaxScaler()
data_scaled = min_max_scaler.fit_transform(values)

# rozdelime na trenovaci a testovaci mnozinu
x, y = data_scaled, labels
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# definujeme architekture site
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(5, activation=tf.nn.sigmoid))
model.add(tf.keras.layers.Dense(3, activation=tf.nn.softmax))

# nastavime optimalizaci
model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# natrenujeme sit na trenovacich datech
model.fit(x_train, y_train, epochs=200, verbose=0)

# %% [markdown]
# Zkusíme si predikovat výstup na testovacích datech a spočítat chybu.

# %%
# predikce na test datech
predictions = model.predict(x_test)
predicted_classes = np.argmax(predictions, axis=-1)
print(predicted_classes)
model_accuracy = accuracy_score(predicted_classes,y_test)
print(model_accuracy)
# Out:
# 39/39 [==============================] - 0s 936us/step
# [1 1 1 ... 0 1 1]
# 0.5346938775510204

# %% [markdown]
# Na závěr se podíváme pomocí matice konfuze, která má jakožto sloupce predikované labely a jakožto řádky skutečné labely a která nám říká, která třída byla kolikrát dobře nebo zle predikovaná.

# %%
# vykresleni, jak bylo co klasifikovano
confusion_matrix = metrics.confusion_matrix(y_test, predicted_classes)
print(confusion_matrix)

pl.matshow(confusion_matrix)
pl.colorbar()
pl.show()

confusion_matrix = metrics.confusion_matrix(y_test, y_test)
print(confusion_matrix)

pl.matshow(confusion_matrix)
pl.colorbar()
pl.show()
# Out:
# [[240 166   1]
#  [167 404   2]
#  [ 21 213  11]]
# [[407   0   0]
#  [  0 573   0]
#  [  0   0 245]]
